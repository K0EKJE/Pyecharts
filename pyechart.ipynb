# %%
from pyecharts.charts import Bar

bar = Bar()
bar.add_xaxis(["衬衫", "羊毛衫", "雪纺衫", "裤子", "高跟鞋", "袜子"])
bar.add_yaxis("商家A", [5, 20, 36, 10, 75, 90])
# render 会生成本地 HTML 文件，默认会在当前目录生成 render.html 文件
# 也可以传入路径参数，如 bar.render("mycharts.html")
bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="202b9f8ba8bd4534b2461f4cf39766cb" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_202b9f8ba8bd4534b2461f4cf39766cb = echarts.init(
#                     document.getElementById('202b9f8ba8bd4534b2461f4cf39766cb'), 'white', {renderer: 'canvas'});
#                 var option_202b9f8ba8bd4534b2461f4cf39766cb = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...

# %%
from pyecharts.charts import *
from pyecharts.components import Table
from pyecharts import options as opts
from pyecharts.commons.utils import JsCode
import random
import datetime
# from pyecharts.globals import CurrentConfig, NotebookType 
# CurrentConfig.NOTEBOOK_TYPE = NotebookType.JUPYTER_LAB
from pyecharts.globals import CurrentConfig

CurrentConfig.ONLINE_HOST = "https://cdn.kesci.com/lib/pyecharts_assets/"
cate = ['河马', '蟒蛇', '大象', '兔子', '熊猫', '狮子']
data1 = [123, 153, 89, 107, 98, 23]
data2 = [56, 77, 93, 68, 45, 67]

bar = (Bar()
       .add_xaxis(cate)
       .add_yaxis('动物园', data1,category_gap="50%")
       .add_yaxis('野外', data2,category_gap="50%")
       .set_global_opts(title_opts=opts.TitleOpts(title="Bar-基本示例", subtitle="我是副标题"))
      )
#bar.load_javascript()
bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://cdn.kesci.com/lib/pyecharts_assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="fdbd04e254594b7096423d5dd90ba22f" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_fdbd04e254594b7096423d5dd90ba22f = echarts.init(
#                     document.getElementById('fdbd04e254594b7096423d5dd90ba22f'), 'white', {renderer: 'canvas'});
#                 var option_fdbd04e254594b7096423d5dd90ba22f = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...

# %%
pip install echarts-themes-pypkg
# Out:
# ...
#   Created wheel for echarts-themes-pypkg: filename=echarts_themes_pypkg-0.0.3-py3-none-any.whl size=18885 sha256=2d2e17a33363176e022d4572bae84b584d95ddae52835844540680397005c319
#   Stored in directory: /Users/apple/Library/Caches/pip/wheels/28/a3/9e/f97e8b933dd52f4e0646916bf1b344a4c7740140b03b0a2c24
# Successfully built echarts-themes-pypkg
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip unstall jupyter-echarts-pypkg
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install jupyter-echarts-pypkg
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pyecharts
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
